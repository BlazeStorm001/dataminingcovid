# %%
import pandas as pd
import shutil
file = pd.read_csv('D:\Desktop\covid-chestxray-dataset-master\covid-chestxray-dataset-master\metadata.csv')
rowCount  = len(file)
for i in range(rowCount):
 view = file['view'].loc[file.index[i]] 
 filename = file['filename'].loc[file.index[i]]
 source = "D:\\Desktop\\covid-chestxray-dataset-master\\covid-chestxray-dataset-master\\images\\" + filename  
 dest = "D:\\Desktop\\covid-chestxray-dataset-master\\covid-chestxray-dataset-master\\images\\"
 if view == "AP":
  print("img in ap")
  print(filename)
  shutil.copy(source, dest + "\\ap")  
 elif view == "PA":
  print("img in pa")  
  print(filename)
  shutil.copy(source, dest + "\\pa")
# Out:
# img in pa
# auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# img in pa
# auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# img in pa
# auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# img in pa
# auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# img in pa
# nejmc2001573_f1a.jpeg
# img in pa
# nejmc2001573_f1b.jpeg
# img in pa
# ARDSSevere.png
# img in pa
# lancet-case2a.jpg
# img in pa
# lancet-case2b.jpg
# img in ap
# SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg
# img in ap
# SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg
# img in ap
# SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg
# img in pa
# SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg
# img in pa
# SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg
# img in pa
# SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9.jpeg
# img in ap
# SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day5.jpeg
# img in ap
# ...
